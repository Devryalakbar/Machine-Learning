# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
df=pd.read_excel('Telco_customer_churns.xlsx')
df.head()
# Out:
#    CustomerID  Count  ...  CLTV                   Churn Reason
# 0  3668-QPYBK      1  ...  3239   Competitor made better offer
# 1  9237-HQITU      1  ...  2701                          Moved
# 2  9305-CDSKC      1  ...  5372                          Moved
# 3  7892-POOKP      1  ...  5003                          Moved
# 4  0280-XJGEX      1  ...  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
#drop unused features/columns for predictions
df.drop(['Churn Label', 'Churn Score','CLTV', 'Churn Reason'], axis=1, inplace=True) #axis=1 to remove columns
df.head()
# Out:
#    CustomerID  Count        Country  ... Monthly Charges Total Charges  Churn Value
# 0  3668-QPYBK      1  United States  ...           53.85        108.15            1
# 1  9237-HQITU      1  United States  ...           70.70        151.65            1
# 2  9305-CDSKC      1  United States  ...           99.65         820.5            1
# 3  7892-POOKP      1  United States  ...          104.80       3046.05            1
# 4  0280-XJGEX      1  United States  ...          103.70        5036.3            1
#
# [5 rows x 29 columns]

# %%
#check whether there are others unused columns, i.e single value
df['Count'].unique()
# Out:
# array([1])

# %%
df['Country'].unique
# Out:
# <bound method Series.unique of 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 7038    United States
# 7039    United States
# 7040    United States
# 7041    United States
# 7042    United States
# Name: Country, Length: 7043, dtype: object>

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['California'], dtype=object)

# %%
df.drop(['CustomerID','Count','Country','State','Lat Long'], axis=1, inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude  ...  Monthly Charges Total Charges Churn Value
# 0  Los Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df['City'].unique()
# Out:
# array(['Los Angeles', 'Beverly Hills', 'Huntington Park', ..., 'Standish',
#        'Tulelake', 'Olympic Valley'], dtype=object)

# %%
# to draw tree, remove all whitespaces
df['City'].replace(' ','_', regex=True,inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude  ...  Monthly Charges Total Charges Churn Value
# 0  Los_Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los_Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los_Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los_Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los_Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df['City'].unique()[0:10]
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', 'Lynwood',
#        'Marina_Del_Rey', 'Inglewood', 'Santa_Monica', 'Torrance',
#        'Whittier', 'La_Habra'], dtype=object)

# %%
#replace whitespace in the column names, requirement for drawing the tree

df.columns = df.columns.str.replace(' ','_')
df.head()
# Out:
#           City  Zip_Code   Latitude  ...  Monthly_Charges Total_Charges Churn_Value
# 0  Los_Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los_Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los_Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los_Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los_Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df['Phone_Service'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Total_Charges'].unique()
# Out:
# array([108.15, 151.65, 820.5, ..., 7362.9, 346.45, 6844.5], dtype=object)

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-eda391cc01c5> in <module>()
# ----> 1 df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     151         try:
#     152             values = lib.maybe_convert_numeric(
# --> 153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#     155         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 2234

# %%
len(df.loc[df['Total_Charges']== ' '])
# Out:
# 11

# %%
df.loc[df['Total_Charges']== ' ']  #NULL, NA
# Out:
#                 City  Zip_Code  ...  Total_Charges  Churn_Value
# 2234  San_Bernardino     92408  ...                           0
# 2438    Independence     93526  ...                           0
# 2568       San_Mateo     94401  ...                           0
# 2667       Cupertino     95014  ...                           0
# 2856        Redcrest     95569  ...                           0
# 4331     Los_Angeles     90029  ...                           0
# 4687        Sun_City     92585  ...                           0
# 5104      Ben_Lomond     95005  ...                           0
# 5719        La_Verne     91750  ...                           0
# 6772            Bell     90201  ...                           0
# 6840      Wilmington     90744  ...                           0
#
# [11 rows x 24 columns]

# %%
#perbaiki : opsi : delete atau ubah data jadi 0 
df.loc[(df['Total_Charges']== ' '), 'Total_Charges'] = 0

# %%
#karena Tenure_Months is 0 ?

df.loc[df['Tenure_Months'] == 0]
# Out:
#                 City  Zip_Code  ...  Total_Charges  Churn_Value
# 2234  San_Bernardino     92408  ...              0            0
# 2438    Independence     93526  ...              0            0
# 2568       San_Mateo     94401  ...              0            0
# 2667       Cupertino     95014  ...              0            0
# 2856        Redcrest     95569  ...              0            0
# 4331     Los_Angeles     90029  ...              0            0
# 4687        Sun_City     92585  ...              0            0
# 5104      Ben_Lomond     95005  ...              0            0
# 5719        La_Verne     91750  ...              0            0
# 6772            Bell     90201  ...              0            0
# 6840      Wilmington     90744  ...              0            0
#
# [11 rows x 24 columns]

# %%
#Sudah tidak ada yang NULL/NA mari kita ubah tipe datanya

df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %%
#hilangkan semua whitespaces DI SEMUA DATA, SEMUA KOLOM agar bisa gambar
df.replace(' ','_', regex=True, inplace=True)
df.head()
# Out:
#           City  Zip_Code  ...  Total_Charges  Churn_Value
# 0  Los_Angeles     90003  ...         108.15            1
# 1  Los_Angeles     90005  ...         151.65            1
# 2  Los_Angeles     90006  ...         820.50            1
# 3  Los_Angeles     90010  ...        3046.05            1
# 4  Los_Angeles     90015  ...        5036.30            1
#
# [5 rows x 24 columns]

# %%
#Hmm...masih ada tipe data OBJECT ? sementara XGB only allows int, float or boolean

# %%
# buat data independent
X = df.drop('Churn_Value', axis=1).copy()
X.head()
# Out:
#           City  Zip_Code  ...  Monthly_Charges  Total_Charges
# 0  Los_Angeles     90003  ...            53.85         108.15
# 1  Los_Angeles     90005  ...            70.70         151.65
# 2  Los_Angeles     90006  ...            99.65         820.50
# 3  Los_Angeles     90010  ...           104.80        3046.05
# 4  Los_Angeles     90015  ...           103.70        5036.30
#
# [5 rows x 23 columns]

# %%
# buat data dependent
y = df['Churn_Value'].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %%
#XGB only support continuous data
#convert categorical data into multiple columns of binary value : One-Hot-Encoding
#terapkan untuk data categorical

df['Payment_Method'].unique()
# Out:
# array(['Mailed_check', 'Electronic_check', 'Bank_transfer_(automatic)',
#        'Credit_card_(automatic)'], dtype=object)

# %%
#coba terapkan 

pd.get_dummies(X, columns=['Payment_Method'])
X.head()

pd.get_dummies(X, columns=['Payment_Method']).head()
# Out:
#           City  ...  Payment_Method_Mailed_check
# 0  Los_Angeles  ...                            1
# 1  Los_Angeles  ...                            0
# 2  Los_Angeles  ...                            0
# 3  Los_Angeles  ...                            0
# 4  Los_Angeles  ...                            0
#
# [5 rows x 26 columns]

# %%
#lakukan buat semua tipe OBJECT

X_encoded = pd.get_dummies(X,
	columns =['City',
		'Gender',
		'Senior_Citizen',
		'Partner',
		'Dependents',
		'Phone_Service',
		'Multiple_Lines',
		'Internet_Service',
		'Online_Security',
		'Online_Backup', 
		'Device_Protection', 
		'Tech_Support', 
		'Streaming_TV',
		'Streaming_Movies', 
		'Contract', 
		'Paperless_Billing', 
		'Payment_Method'])
X_encoded.head()
# Out:
#    Zip_Code  ...  Payment_Method_Mailed_check
# 0     90003  ...                            1
# 1     90005  ...                            0
# 2     90006  ...                            0
# 3     90010  ...                            0
# 4     90015  ...                            0
#
# [5 rows x 1178 columns]

# %%
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %%
#Split the data agar proporsi yang left seimbang di train dan test

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=42, stratify=y)

# %%
sum(y_train)/len(y_train)
sum(y_test)/len(y_test)
sum(y_train)/len(y_train), sum(y_test)/len(y_test)
# Out:
# (0.2654297614539947, 0.26519023282226006)

# %%
#create the model

clf_xgb = xgb.XGBClassifier(objective='binary:logistic', missing=None, seed=42)
clf_xgb.fit(X_train, 
	          y_train,
	          verbose=True, 
            early_stopping_rounds=10,
            eval_metric='aucpr',
	          eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-aucpr:0.578392
# Will train until validation_0-aucpr hasn't improved in 10 rounds.
# [1]	validation_0-aucpr:0.580597
# [2]	validation_0-aucpr:0.590099
# [3]	validation_0-aucpr:0.601636
# [4]	validation_0-aucpr:0.608932
# [5]	validation_0-aucpr:0.603821
# [6]	validation_0-aucpr:0.618314
# [7]	validation_0-aucpr:0.610906
# [8]	validation_0-aucpr:0.620122
# [9]	validation_0-aucpr:0.62495
# [10]	validation_0-aucpr:0.629252
# [11]	validation_0-aucpr:0.628517
# [12]	validation_0-aucpr:0.650051
# [13]	validation_0-aucpr:0.649035
# [14]	validation_0-aucpr:0.650546
# [15]	validation_0-aucpr:0.652876
# [16]	validation_0-aucpr:0.654922
# [17]	validation_0-aucpr:0.655347
# [18]	validation_0-aucpr:0.655818
# [19]	validation_0-aucpr:0.655958
# [20]	validation_0-aucpr:0.656236
# [21]	validation_0-aucpr:0.655564
# [22]	validation_0-aucpr:0.656688
# [23]	validation_0-aucpr:0.657409
# [24]	validation_0-aucpr:0.656236
# [25]	validation_0-aucpr:0.655347
# [26]	validation_0-aucpr:0.656541
# [27]	validation_0-aucpr:0.657225
# [28]	validation_0-aucpr:0.656978
# [29]	validation_0-aucpr:0.657309
# [30]	validation_0-aucpr:0.65767
# [31]	validation_0-aucpr:0.658044
# [32]	validation_0-aucpr:0.659631
# [33]	validation_0-aucpr:0.660315
# [34]	validation_0-aucpr:0.659643
# [35]	validation_0-aucpr:0.660104
# [36]	validation_0-aucpr:0.659014
# [37]	validation_0-aucpr:0.659666
# [38]	validation_0-aucpr:0.661717
# [39]	validation_0-aucpr:0.662989
# [40]	validation_0-aucpr:0.663667
# [41]	validation_0-aucpr:0.662927
# [42]	validation_0-aucpr:0.663886
# [43]	validation_0-aucpr:0.664187
# [44]	validation_0-aucpr:0.6642
# [45]	validation_0-aucpr:0.665552
# [46]	validation_0-aucpr:0.665049
# [47]	validation_0-aucpr:0.664782
# [48]	validation_0-aucpr:0.66522
# [49]	validation_0-aucpr:0.665371
# [50]	validation_0-aucpr:0.664722
# [51]	validation_0-aucpr:0.664562
# [52]	validation_0-aucpr:0.665216
# [53]	validation_0-aucpr:0.665086
# [54]	validation_0-aucpr:0.664534
# [55]	validation_0-aucpr:0.664162
# Stopping. Best iteration:
# [45]	validation_0-aucpr:0.665552
# XGBClassifier(seed=42)

# %%
#Check the accuracy
plot_confusion_matrix(clf_xgb,
			X_test, 
			y_test,
			values_format='d',
			display_labels=["Did not leave", "Left"])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#1178/1294 = 91%
#239/467   = 51%

# %%
#....singkat cerita, ketemu optimisasi paramnya

clf_xgb = xgb.XGBClassifier(seed=42,
			objective='binary:logistic',
			gamma=0.25,
			learn_rate=0.1,
			max_depth=4,
			reg_lambda=10,
			scale_pos_weight=3,
			subsample=0.9,
			colsample_bytree=0.5)

clf_xgb.fit(X_train, 
	          y_train,
	          verbose=True, 
            early_stopping_rounds=10,
            eval_metric='aucpr',
	          eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-aucpr:0.53278
# Will train until validation_0-aucpr hasn't improved in 10 rounds.
# [1]	validation_0-aucpr:0.614654
# [2]	validation_0-aucpr:0.62623
# [3]	validation_0-aucpr:0.632985
# [4]	validation_0-aucpr:0.630432
# [5]	validation_0-aucpr:0.630932
# [6]	validation_0-aucpr:0.63177
# [7]	validation_0-aucpr:0.634766
# [8]	validation_0-aucpr:0.634402
# [9]	validation_0-aucpr:0.635058
# [10]	validation_0-aucpr:0.635457
# [11]	validation_0-aucpr:0.635323
# [12]	validation_0-aucpr:0.635502
# [13]	validation_0-aucpr:0.640483
# [14]	validation_0-aucpr:0.639526
# [15]	validation_0-aucpr:0.639647
# [16]	validation_0-aucpr:0.653324
# [17]	validation_0-aucpr:0.655414
# [18]	validation_0-aucpr:0.654974
# [19]	validation_0-aucpr:0.651737
# [20]	validation_0-aucpr:0.651866
# [21]	validation_0-aucpr:0.656086
# [22]	validation_0-aucpr:0.65352
# [23]	validation_0-aucpr:0.653576
# [24]	validation_0-aucpr:0.651395
# [25]	validation_0-aucpr:0.650606
# [26]	validation_0-aucpr:0.649366
# [27]	validation_0-aucpr:0.645388
# [28]	validation_0-aucpr:0.650234
# [29]	validation_0-aucpr:0.650764
# [30]	validation_0-aucpr:0.650682
# [31]	validation_0-aucpr:0.655777
# Stopping. Best iteration:
# [21]	validation_0-aucpr:0.656086
# XGBClassifier(colsample_bytree=0.5, gamma=0.25, learn_rate=0.1, max_depth=4,
#               reg_lambda=10, scale_pos_weight=3, seed=42, subsample=0.9)

# %%
#Check the accuracy again
plot_confusion_matrix(clf_xgb,
			X_test, 
			y_test,
			values_format='d',
			display_labels=["Did not leave", "Left"])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#left 	      
print(388/(388+79)*100)
# Out:
# 83.08351177730194

# %%
#did not leave
print(923/(923+371)*100)
# Out:
# 71.32921174652242

# %%
#and let draw the tree !
clf_xgb = xgb.XGBClassifier(seed=42,
			objective='binary:logistic',
			gamma=0.25,
			learn_rate=0.1,
			max_depth=4,
			reg_lambda=10,
			scale_pos_weight=3,
			subsample=0.9,
			colsample_bytree=0.5,
			n_estimators=1) # We set this to 1 so we can get gain, cover, etc
clf_xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(colsample_bytree=0.5, gamma=0.25, learn_rate=0.1, max_depth=4,
#               n_estimators=1, reg_lambda=10, scale_pos_weight=3, seed=42,
#               subsample=0.9)

# %%
bst = clf_xgb.get_booster()
for importance_type in ('weight', 'gain', 'cover', 'total_gain', 'total_cover'):
  print('%s: ' % importance_type, bst.get_score(importance_type=importance_type))

node_params = { 'shape' : 'box',
		'style' : 'filled, rounded',
		'fillcolor': '#78cbe'}
leaf_params = { 'shape' : 'box',
		'style' : 'filled, rounded',
		'fillcolor': '#e48038'}

xgb.to_graphviz(clf_xgb, num_trees=0, size="10,10",
		condition_node_params=node_params,
		leaf_node_params=leaf_params)
# Out:
# weight:  {'Contract_Month-to-month': 22, 'Monthly_Charges': 56, 'Online_Security_No': 13, 'Dependents_No': 46, 'Internet_Service_Fiber_optic': 9, 'Tenure_Months': 53, 'Contract_One_year': 3, 'City_San_Bernardino': 2, 'Streaming_Movies_Yes': 5, 'Zip_Code': 35, 'Tech_Support_No': 9, 'Payment_Method_Electronic_check': 9, 'Contract_Two_year': 10, 'Paperless_Billing_No': 13, 'Total_Charges': 30, 'Longitude': 16, 'Multiple_Lines_No': 10, 'Online_Backup_No': 6, 'City_Sacramento': 2, 'Streaming_TV_Yes': 2, 'Latitude': 15, 'Partner_No': 4, 'Streaming_TV_No': 1, 'Online_Security_Yes': 1, 'City_Bakersfield': 1, 'Internet_Service_DSL': 1}
# gain:  {'Contract_Month-to-month': 185.31532615136365, 'Monthly_Charges': 11.468307095214287, 'Online_Security_No': 50.17990116461538, 'Dependents_No': 26.362582901739135, 'Internet_Service_Fiber_optic': 84.06228055555556, 'Tenure_Months': 26.017658504528306, 'Contract_One_year': 14.445415500000001, 'City_San_Bernardino': 2.2270813, 'Streaming_Movies_Yes': 14.622358334000001, 'Zip_Code': 6.452780061714287, 'Tech_Support_No': 63.567926362222224, 'Payment_Method_Electronic_check': 33.234326674, 'Contract_Two_year': 24.169031424, 'Paperless_Billing_No': 15.393680317692308, 'Total_Charges': 10.281004728299994, 'Longitude': 4.69137788, 'Multiple_Lines_No': 8.791055056000001, 'Online_Backup_No': 13.741040876666668, 'City_Sacramento': 1.516669275, 'Streaming_TV_Yes': 9.16472149, 'Latitude': 4.413210828666666, 'Partner_No': 8.5752181975, 'Streaming_TV_No': 5.50534248, 'Online_Security_Yes': 1.73302579, 'City_Bakersfield': 4.73432541, 'Internet_Service_DSL': 0.818986654}
# cover:  {'Contract_Month-to-month': 777.7188949681819, 'Monthly_Charges': 301.7053031767858, 'Online_Security_No': 612.6695315, 'Dependents_No': 449.93661284782604, 'Internet_Service_Fiber_optic': 512.5460603333333, 'Tenure_Months': 480.093353535849, 'Contract_One_year': 389.0874836666667, 'City_San_Bernardino': 249.7770235, 'Streaming_Movies_Yes': 302.5171266, 'Zip_Code': 101.83815283857142, 'Tech_Support_No': 782.7236222955556, 'Payment_Method_Electronic_check': 695.3859924888889, 'Contract_Two_year': 546.3329316, 'Paperless_Billing_No': 491.52497969230774, 'Total_Charges': 243.53836046200004, 'Longitude': 113.30020250624997, 'Multiple_Lines_No': 323.73771509999995, 'Online_Backup_No': 582.7894416666667, 'City_Sacramento': 56.5700588, 'Streaming_TV_Yes': 661.137787, 'Latitude': 304.12495234200003, 'Partner_No': 652.45994575, 'Streaming_TV_No': 408.383423, 'Online_Security_Yes': 2.28484964, 'City_Bakersfield': 329.158661, 'Internet_Service_DSL': 3.09249496}
# total_gain:  {'Contract_Month-to-month': 4076.93717533, 'Monthly_Charges': 642.2251973320001, 'Online_Security_No': 652.33871514, 'Dependents_No': 1212.6788134800001, 'Internet_Service_Fiber_optic': 756.5605250000001, 'Tenure_Months': 1378.9359007400003, 'Contract_One_year': 43.3362465, 'City_San_Bernardino': 4.4541626, 'Streaming_Movies_Yes': 73.11179167, 'Zip_Code': 225.84730216000003, 'Tech_Support_No': 572.11133726, 'Payment_Method_Electronic_check': 299.108940066, 'Contract_Two_year': 241.69031424, 'Paperless_Billing_No': 200.11784413, 'Total_Charges': 308.4301418489998, 'Longitude': 75.06204608, 'Multiple_Lines_No': 87.91055056, 'Online_Backup_No': 82.44624526000001, 'City_Sacramento': 3.03333855, 'Streaming_TV_Yes': 18.32944298, 'Latitude': 66.19816243, 'Partner_No': 34.30087279, 'Streaming_TV_No': 5.50534248, 'Online_Security_Yes': 1.73302579, 'City_Bakersfield': 4.73432541, 'Internet_Service_DSL': 0.818986654}
# total_cover:  {'Contract_Month-to-month': 17109.8156893, 'Monthly_Charges': 16895.496977900002, 'Online_Security_No': 7964.703909499999, 'Dependents_No': 20697.084190999998, 'Internet_Service_Fiber_optic': 4612.914543, 'Tenure_Months': 25444.947737399998, 'Contract_One_year': 1167.262451, 'City_San_Bernardino': 499.554047, 'Streaming_Movies_Yes': 1512.585633, 'Zip_Code': 3564.3353493499994, 'Tech_Support_No': 7044.51260066, 'Payment_Method_Electronic_check': 6258.4739324, 'Contract_Two_year': 5463.329316, 'Paperless_Billing_No': 6389.8247360000005, 'Total_Charges': 7306.150813860001, 'Longitude': 1812.8032400999996, 'Multiple_Lines_No': 3237.3771509999997, 'Online_Backup_No': 3496.73665, 'City_Sacramento': 113.1401176, 'Streaming_TV_Yes': 1322.275574, 'Latitude': 4561.87428513, 'Partner_No': 2609.839783, 'Streaming_TV_No': 408.383423, 'Online_Security_Yes': 2.28484964, 'City_Bakersfield': 329.158661, 'Internet_Service_DSL': 3.09249496}
